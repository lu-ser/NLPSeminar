# %% [markdown]
# ### WebScraping with LLMs

# %%
# %pip install -qU langchain-groq

# %%
import requests
import json
from bs4 import BeautifulSoup
from langchain_groq import ChatGroq
from google.colab import userdata
import getpass
import os
if "GROQ_API_KEY" not in os.environ:
    try:
        os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
    except Exception as e:
        os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")

# %%
# Configure the Groq client
llm_Groq = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

def fetch_page(url):
    """Performs a GET request on the page and returns its content."""
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.text
    else:
        return None

def clean_html(html):
    """Removes HTML tags and returns only the raw text."""
    soup = BeautifulSoup(html, "html.parser")
    return soup.get_text(separator="\n").strip()

def extract_info(content, task):
    """Uses Groq LLaMA 3.1 to extract specific information."""
    prompt = f"""
    I will provide you with the content of a news article. Extract only the {task} without any additional text.

    Article:
    {content[:4000]}  # Limit the length to avoid errors

    Expected result:
    """
    response = llm_Groq.invoke(prompt)
    return response.content.strip()

def scrape_news(url):
    """Scrapes the page and uses agents to extract information."""
    content = fetch_page(url)
    if not content:
        return {"error": "Unable to retrieve content"}

    clean_content = clean_html(content)
    title = extract_info(clean_content, "article title")
    text = extract_info(clean_content, "full article text")
    date_author = extract_info(clean_content, "publication date and author, british format - MM/DD/YYYY")

    return {
        "title": title,
        "text": text,
        "date_author": date_author
    }

# Esempio di utilizzo
url = "https://www.ilmessaggero.it/italia/terremoto_campi_flegrei_oggi_napoli_sciame_sismico_scuole_evacuate_fuorigrotta-8637855.html"
data = scrape_news(url)
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "title": "Terremoto Napoli Campi Flegrei, registrate oltre 40 scosse: la più forte da 3.1. Scuole evacuate a Fuorigrotta",
#   "text": "Terremoto Napoli Campi Flegrei, registrate oltre 40 scosse: la più forte da 3.1. Scuole evacuate a Fuorigrotta\n\n Il sisma è stato avvertito in tantissime zone della città (Pianura, Fuorigrotta) e province (Quarto, Arco Felice)\n\n3 Minuti di Lettura\n\nMercoledì  5 Febbraio 2025, 09:19                            \n - Ultimo aggiornamento: 11:41\n\nOre 18\n - \nNewsletter\n\nIl punto serale sulle notizie del giorno\n\n\nIscriviti\n e ricevi le notizie via email\n\nTerremoto\n ai \nCampi Flegrei\n. Un nuovo sciame sismico ha fatto tremare ancora una volta la zona di Napoli. La scossa più forte fino ad ora registrata è stata di 3.1 alle ore 8.52 alla profondità di 2.7 km con epicentro zona Pisciarelli ad Agnano. Il sisma è stato sentito in tantissime zone della città (Pianura, Fuorigrotta) e province (Quarto, Arco Felice).  #",
#   "date_author": "02/05/2025 \nLorenzo Rovagnati"
# }

# %% [markdown]
# ## Dataset Augementation with LLMs

# %%
# !git clone https://github.com/usc-isi-i2/logical-fallacy-identification.git
# Out:
# Cloning into 'logical-fallacy-identification'...
# remote: Enumerating objects: 5208, done.
# remote: Counting objects: 100% (1045/1045), done.
# remote: Compressing objects: 100% (395/395), done.
# remote: Total 5208 (delta 704), reused 978 (delta 641), pack-reused 4163 (from 1)
# Receiving objects: 100% (5208/5208), 228.95 MiB | 11.21 MiB/s, done.
# Resolving deltas: 100% (1611/1611), done.

# %%
import pandas as pd
import random
from langchain_groq import ChatGroq
max_length = 100
df = pd.read_csv("logical-fallacy-identification/data/fallacy_train.csv")[["sentence", "fine_class"]]
# Filter out sentences that are too long
df_filtered = df[df["sentence"].str.len() <= max_length]
df_filtered.head()
# Out:
#                                             sentence             fine_class
# 1  All writing teachers must be awesome because M...  faulty generalization
# 2  If we teach anton how to drive the car, he’ll ...  faulty generalization
# 3  Labor unions in America are just as bad as Rus...   fallacy of relevance
# 4  America:  love it or leave it. Either you’re f...          false dilemma
# 5  claiming that an idea or belief is true simply...             ad populum

# %%
# Select N random rows
N = 5  # Change this value to select more or fewer rows
df_sample = df_filtered.sample(N)

# %%
llm_Groq = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# %%
# Function to generate a news-like text incorporating the fallacious sentence
def generate_news(sentence, fine_class):
    prompt = f"""Write a short news article (3-4 sentences) that naturally incorporates the following fallacious statement.
    The statement must be included exactly as it is, without quotation marks. Ensure it is well integrated into the news context.
    \nStatement: {sentence}\nFallacy type: {fine_class}\n\nNews article:"""
    return llm_Groq.invoke(prompt).content

# Generate news articles for the selected sentences
results = []
for _, row in df_sample.iterrows():
    news = generate_news(row["sentence"], row["fine_class"])
    results.append({"sentence": row["sentence"], "fine_class": row["fine_class"], "generated_news": news})

# Create a DataFrame with the results
df_results = pd.DataFrame(results)

# Print the results
for _, row in df_results.iterrows():
    print(f"Fallacy: {row['fine_class']}")
    print(f"Sentence: {row['sentence']}")
    print(f"Generated News: {row['generated_news']}\n")
# Out:
# Fallacy: fallacy of logic
# Sentence: All judges are fair-minded individuals;  therefore, Judge Ito is fair in his decisions.
# Generated News: A recent study has found that the number of appeals in the US court system has decreased significantly since the implementation of a new judicial training program aimed at improving judges' decision-making skills. The program, which focuses on empathy and critical thinking, has been credited with reducing the number of disputed verdicts. All judges are fair-minded individuals; therefore, Judge Ito is fair in his decisions. As a result, many are hailing the program as a major success in promoting fairness and justice in the American judicial system.
#
# Fallacy: fallacy of logic
# Sentence: Good people don't lie. You told a lie. Therefore, you are not a good person.
# Generated News: A local politician has come under fire after being accused of misrepresenting their voting record in a recent campaign speech. Critics argue that the politician's actions demonstrate a lack of transparency and accountability, which are essential qualities for public officials. However, some supporters have taken to social media to defend the politician, claiming that Good people don't lie. You told a lie. Therefore, you are not a good person, and that the politician's mistake should not define their character.
#
# Fallacy: fallacy of logic
# Sentence: We should stop using hairspray because it is snowing in New York.
# Generated News: A severe winter storm has hit the northeastern United States, bringing heavy snowfall to major cities including New York. The city's airports have been shut down, and thousands of flights have been canceled. As residents struggle to navigate the treacherous roads, some are questioning the safety of their daily routines, including the use of hairspray. We should stop using hairspray because it is snowing in New York.
#
# Fallacy: false dilemma
# Sentence: “Live with me or live on the streets”
# Generated News: A new homeless shelter in downtown Los Angeles has sparked controversy among local residents, with some arguing that the facility will attract more homeless individuals to the area. Critics claim that the shelter's proximity to a popular neighborhood will lead to increased crime and property values will plummet. However, supporters of the shelter argue that it will provide a vital service to those in need, and that the city has a responsibility to provide housing options for its most vulnerable citizens. The shelter's director, Jane Smith, said that the city has a limited budget and that people have a choice: Live with me or live on the streets.
#
# Fallacy: intentional
# Sentence: Using a double standard or arguing for an unjustified exception.
# Generated News: A recent proposal to increase funding for local arts programs has sparked controversy among city officials. Critics argue that the allocation of funds would unfairly benefit a select group of artists, while others in the community struggle to make ends meet. However, supporters of the proposal point out that the city has a history of providing tax breaks to large corporations, which they claim is a double standard or arguing for an unjustified exception, as these companies often have the resources to pay their fair share. The debate is set to continue at the city council meeting next week.

# %%
df_results.head()
# Out:
#                                             sentence        fine_class  \
# 0  All judges are fair-minded individuals;  there...  fallacy of logic
# 1  Good people don't lie. You told a lie. Therefo...  fallacy of logic
# 2  We should stop using hairspray because it is s...  fallacy of logic
# 3              “Live with me or live on the streets”     false dilemma
# 4  Using a double standard or arguing for an unju...       intentional
#
#                                       generated_news
# 0  A recent study has found that the number of ap...
# 1  A local politician has come under fire after b...
# 2  A severe winter storm has hit the northeastern...
# 3  A new homeless shelter in downtown Los Angeles...
# 4  A recent proposal to increase funding for loca...

# %% [markdown]
# ### Simple Hallucination Detection Framework

# %%
from difflib import SequenceMatcher

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def check_hallucination(text, k=2, similarity_threshold=0.1):
    llm_Groq = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

    # Get original response
    original_response = llm_Groq.invoke(text).content
    print("Original Response:", original_response)

    # Generate additional responses with high temperature
    llm_Groq_varied = ChatGroq(model="llama-3.1-8b-instant", temperature=1)
    responses = []
    for i in range(k):
        response = llm_Groq_varied.invoke(text).content
        responses.append(response)
        print(f"Response {i+1} with high temperature:", response)

    # Check similarity
    similarity_inconsistency = any(similar(original_response, resp) < similarity_threshold for resp in responses)

    # Model consistency check
    inconsistency_check_prompt = f"""Given the following prompt and responses, are there any inconsistencies?
    Prompt: '{text}'
    Original response: '{original_response}'
    Additional responses:
    {' '.join([f'Response {i+1}: {resp}' for i, resp in enumerate(responses)])}

    Respond with only 'True' if there are inconsistencies, or 'False' if there are no inconsistencies."""

    model_inconsistency = llm_Groq.invoke(inconsistency_check_prompt).content.strip().lower() == 'true'

    print("Model inconsistency check result:", "True" if model_inconsistency else "False")

    return "Potential hallucination detected." if (similarity_inconsistency or model_inconsistency) else "No hallucination detected."

# %%
prompts = [
        "Provide academic paper citations about the impact of moonlight on deep-sea coral growth",
        "10+15*2"
    ]
for i, prompt in enumerate(prompts, 1):
    print(f"\\nChecking prompt {i}: {prompt}")
    result = check_hallucination(prompt)
    print(f"Final result of hallucination check for prompt {i}: {result}\\n")
# Out:
# \nChecking prompt 1: Provide academic paper citations about the impact of moonlight on deep-sea coral growth
# Original Response: Unfortunately, I couldn't find any specific academic papers that directly address the impact of moonlight on deep-sea coral growth. However, I can provide some relevant studies that discuss the effects of light on deep-sea corals and the importance of lunar cycles in marine ecosystems.
#
# 1. **Hochberg, E. J., & Butman, C. A. (1985).** "Deep-sea coral reefs: Upwelling centers and associated food webs on the Pacific outer shelf." Journal of Marine Research, 43(2), 251-275. (This study discusses the importance of upwelling and associated food webs on deep-sea coral reefs, but does not specifically address the impact of moonlight.)
#
# 2. **Roberts, J. M., et al. (2009).** "Ecological characteristics of deep-water coral reefs." Current Biology, 19(16), R129-R134. (This review article discusses the ecological characteristics of deep-water coral reefs, including the importance of light and food availability, but does not specifically address the impact of moonlight.)
#
# 3. **Bongaerts, P., et al. (2010).** "Deep-water coral reefs of the Red Sea: A review of the current state of knowledge." Marine Ecology Progress Series, 408, 273-291. (This study discusses the ecology and biodiversity of deep-water coral reefs in the Red Sea, but does not specifically address the impact of moonlight.)
#
# 4. **Helmle, R. P., et al. (2011).** "Lunar cycles and the ecology of deep-sea corals." Marine Ecology Progress Series, 433, 147-155. (This study discusses the importance of lunar cycles in the ecology of deep-sea corals, including the impact of tidal currents and food availability, but does not specifically address the impact of moonlight.)
#
# 5. **Bongaerts, P., et al. (2013).** "Deep-water coral reefs of the Indo-Pacific: A review of the current state of knowledge." Marine Ecology Progress Series, 486, 1-19. (This review article discusses the ecology and biodiversity of deep-water coral reefs in the Indo-Pacific region, but does not specifically address the impact of moonlight.)
#
# 6. **Kroeker, K. J., et al. (2013).** "Effects of ocean acidification on marine organisms: Quantifying sensitivities and interaction with warming." Global Change Biology, 19(1), 188-208. (This review article discusses the impacts of ocean acidification and warming on marine organisms, including corals, but does not specifically address the impact of moonlight.)
#
# 7. **Baker, A. C., et al. (2016).** "The effects of light on the growth and survival of the deep-sea coral Lophelia pertusa." Marine Biology, 163(10), 2211-2223. (This study discusses the effects of light on the growth and survival of the deep-sea coral Lophelia pertusa, but does not specifically address the impact of moonlight.)
#
# 8. **Helmle, R. P., et al. (2017).** "Lunar cycles and the ecology of deep-sea corals: A review." Marine Ecology Progress Series, 573, 1-15. (This review article discusses the importance of lunar cycles in the ecology of deep-sea corals, including the impact of tidal currents and food availability, but does not specifically address the impact of moonlight.)
#
# Please note that these studies do not provide direct evidence of the impact of moonlight on deep-sea coral growth. However, they do highlight the importance of light and lunar cycles in the ecology of deep-sea corals.
# Response 1 with high temperature: Unfortunately, I couldn't find specific references to peer-reviewed studies or academic papers directly addressing the effect of moonlight on deep-sea coral growth. However, I can provide some general research papers and their abstracts that discuss the impact of light on coral growth and potentially help you find more information.
#
# 1. **Selig, E. R., & Denny, M. W. (1995).**
#
#    "Lessons in resolving inconspicuous hypotheses: A review of some case studies"
#
#    *Published in: Journal of Experimental Marine Biology and Ecology*
#
#    They dealt with indirect light and its effects on various deep marine colonizations, this did help point out that the presence of any slight ambient illumination is particularly indispensable for colonies.
#
#    Abstract: They hypothesized that a relationship between elevated organism size estimates and sampling dates could be resolved, but the inconspicuous problem set presented no connection with that data when analyzed on the background provided within these methods. The effects of elevated light upon shallow-water algal grazers and the mechanism used in that determination would definitely warrant scientific analysis.
#
#    My criticism  - their research was fairly removed from those relating to full moon’s effects moonlight’s effects. This doesn't give a clearer outline what deep-sea coral could look like directly if exposed to our, as we know, full moon phases however it seems it gets even worse and likely continues off.
#
# 2. **Franklin, A. J, Lopez, J. L, & Rodriguez, I. K. (2016)**
#
#    "Quantification of Artificial Light Effects on Corals during the 2015 Bleaching Event on the Great Barrier Reef."
#
#    *Published in: Scientific Reports,*
#
#    They talk extensively on light effect variability on corals under several conditions but also acknowledged environmental pressures in certain reef circumstances from direct illumination would give most accurate results on it specifically.
#
#    Their data collected implied various outcomes in response to exposure from light sources depending on the variety, quality, quantity as well as conditions in a tropical coral ecosystem.
#
#    Abstracts: They reported quantitative measures of coral responses to artificial light in 2015 GBR Bleaching investigation showing evidence some type of damage that can be specifically attributed yet not general across reef framework over much sampled 2014 bleaching event from mass coral die-off recovery process as more than over a year following for their research.
#
#    Furthermore in response to constant high light stimulation experienced in summer 2015 certain patterns arise under these studies yet suggest coral death should not occur due mainly other causes yet still had some sort similar patterns under said stressor.
# Response 2 with high temperature: I've searched for academic papers related to the impact of moonlight on deep-sea coral growth. However, it's essential to note that the availability of research on this specific topic is limited. Deep-sea corals are adapted to darkness, and moonlight effects may be minimal.
#
# Here are a few academic paper citations that discuss relevant topics or indirect relationships:
#
# 1. **Loya, Y.**, & **Collin, R.** (1999). **Effect of moonlight on the photosynthetic activity of coral-dinoflagellate symbiosis.** Marine biology, 133(2), 257-264.
#
# - This study discusses how moonlight affects the photosynthetic activity of coral-dinoflagellate symbiosis but not specifically deep-sea corals.
#
# 2. **Hämäläinen, H.**, & **Räihälä, K.** (2011). **Photosynthesis and respiration in relation to depth and oxygen levels in deep-water coral gardens.** Journal of Experimental Marine Biology and Ecology, 409(1-2), 81-89.
#
# - This study investigates the photosynthetic and respiratory characteristics of deep-water corals but does not mention moonlight as a variable.
#
# 3. **Wunsch, M.**, **Holmes, K. E.**, & **West, J. M.** (2013). **Physiological responses of the deep-sea coral, Primnoa resedae, to darkness and depth.** Journal of Experimental Marine Biology and Ecology, 461, 44-54.
#
# - This study looks at the physiological responses of deep-sea corals to darkness and depth. However, moonlight effects are not discussed.
#
# 4. **Ranscak, R.**, **Previšić, D.**, & **Haapkylä, S.** (2013). **Timing of nocturnal photosynthesis by shallower-dwelling deep-sea corals.** Marine Ecology Progress Series, 477, 173-184.
#
# - This study is related to nocturnal photosynthesis in some shallow-to-medium water deep-sea corals, which might indirectly relate to moonlight influence, although it does not discuss specific effects.
#
# 5. **Ranscák, R.**, **Previšić, M. D.**, & **Haapkylä, S.** (2017). **Nocturnal coral photosynthesis in the intermediate water of the Mediterranean Sea.** Limnology and Oceanography, 62(2), 629-638.
#
# - In this paper, authors discuss species adapted to 'almost-darkness' but also more shade-tolerant species that might fare better under moonlit situations without concrete discussions about the effect on specific growth rates.
#
# There's limited information on moonlight specifically in relation to deep-sea coral growth that could direct a study or give specifics about known results.
# Model inconsistency check result: True
# Final result of hallucination check for prompt 1: Potential hallucination detected.\n
# \nChecking prompt 2: 10+15*2
# Original Response: To solve this, we need to follow the order of operations (PEMDAS):
#
# 1. Multiply 15 and 2: 15*2 = 30
# 2. Add 10 and 30: 10 + 30 = 40
#
# The answer is 40.
# Response 1 with high temperature: To solve the expression 10 + 15 * 2, we need to follow the order of operations (PEMDAS):
#
# 1. Multiply 15 and 2: 15 * 2 = 30
# 2. Add 10 to the result: 10 + 30 = 40
#
# The answer is 40.
# Response 2 with high temperature: To calculate the expression, follow the order of operations (PEMDAS):
#
# 1. Multiply 15 and 2: 15 * 2 = 30
# 2. Add 10: 10 + 30 = 40
#
# The result is 40.
# Model inconsistency check result: False
# Final result of hallucination check for prompt 2: No hallucination detected.\n
